# %% [markdown]
# # Bidirectional Search

# %% [markdown]
# - [The board](#The-board)
# - [Utils](#Utils)
# - [Main logic](#Main-logic)
# - [Example #1](#Example-#1)
# - [Example #2](#Example-#2)
# - [Example #3](#Example-#3)

# %% [markdown]
# ## The board

# %%
initial_board = [
    1, 2, 3,
    0, 4, 5,
    7, 8, 6
]
target_board = [
    1, 2, 3,
    4, 5, 6,
    7, 8, 0
]
allowed_moves = {}
allowed_moves[0] = [1, 3]
allowed_moves[1] = [0, 2, 4]
allowed_moves[2] = [1, 5]
allowed_moves[3] = [0, 4, 6]
allowed_moves[4] = [1, 3, 5, 7]
allowed_moves[5] = [2, 4, 8]
allowed_moves[6] = [3, 7]
allowed_moves[7] = [4, 6, 8]
allowed_moves[8] = [5, 7]

# %% [markdown]
# ## Utils

# %%
def print_board(board):
    for index in range(3):
        print('{} | {} | {}'.format(board[3 * index + 0], board[3 * index + 1], board[3 * index + 2]))
        
        if index < 2:
            print('---------')

# %%
print_board(initial_board)
# Out:
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6

# %%
print_board(target_board)
# Out:
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0

# %%
def convert_list_to_string(board):
    return ''.join(str(box) for box in board)

def convert_string_to_list(board):
    return [int(box) for box in board]

def get_adyacent_boards(board):
    print('\nInitial board')
    print_board(board)
    index_empty_box = board.index(0)
    indexes_to_place_empty_box = allowed_moves[index_empty_box]
    adjacent_boards = []
    
    for index in indexes_to_place_empty_box:
        new_board = board[:]
        new_board[index_empty_box] = new_board[index]
        new_board[index] = 0
        print('\nNew board')
        print_board(new_board)
        new_board_string = convert_list_to_string(new_board)
        adjacent_boards.append(new_board_string)
        
    return adjacent_boards

# %% [markdown]
# ## Main logic

# %%
def bfs_reconstruct_path(parents, source, target):
    path = [target]
    previous = parents[target]
    
    while previous != source:
        path.append(previous)
        previous = parents[previous]
    
    path.append(source)
    path.reverse()
    return path

def bfs_solve(source, target):
    initial = convert_list_to_string(initial_board)
    target = convert_list_to_string(target_board)
    
    # Set queues
    next_nodes_1 = []
    visited_nodes_1 = set()
    parents_1 = {} # To recreat path
    next_nodes_2 = []
    visited_nodes_2 = set()
    parents_2 = {} # To recreat path
    
    # Add source node first
    next_nodes_1.append(initial)
    visited_nodes_1.add(initial)
    
    next_nodes_2.append(target)
    visited_nodes_2.add(target)
    
    operations_performed = 0
    cycles = 0
    
    while next_nodes_1 and next_nodes_2:
        cycles += 1
        operations_performed += 1
        print('\n-------------------- {}'.format(cycles))
        print('next_nodes_1 = {}'.format(next_nodes_1))
        print('visited_nodes_1 = {}'.format(visited_nodes_1))
        node_1 = next_nodes_1.pop(0)
        
        if (node_1 == target):
            print('\n* Target reached!')
            return operations_performed, parents_1, 1
        
        for adjacent_node in get_adyacent_boards(convert_string_to_list(node_1)):
            if adjacent_node not in visited_nodes_1:
                operations_performed += 1
                next_nodes_1.append(adjacent_node)
                visited_nodes_1.add(adjacent_node)
                parents_1[adjacent_node] = node_1
                
        print('\n\nnext_nodes_2 = {}'.format(next_nodes_2))
        print('visited_nodes_2 = {}'.format(visited_nodes_2))
        node_2 = next_nodes_2.pop(0)
        print('node_2 = {}'.format(node_2))
        print('source = {}'.format(initial))
        
        if (node_2 == initial):
            print('\n* Source reached!')
            return operations_performed, parents_2, 2
        
        for adjacent_node in get_adyacent_boards(convert_string_to_list(node_2)):
            if adjacent_node not in visited_nodes_2:
                operations_performed += 1
                next_nodes_2.append(adjacent_node)
                visited_nodes_2.add(adjacent_node)
                parents_2[adjacent_node] = node_2
        
    return operations_performed, [], 0

def bfs(source, target):
    operations_performed, parents, path = bfs_solve(source, target)
    steps = []
    
    if path == 1:
        steps = bfs_reconstruct_path(parents, convert_list_to_string(source), convert_list_to_string(target))
    elif path == 2:
        steps = bfs_reconstruct_path(parents, convert_list_to_string(target), convert_list_to_string(source))
        steps.reverse()

    return operations_performed, steps, path

# %% [markdown]
# ## Example 1

# %%
operations_performed, steps, path = bfs(initial_board, target_board)
# Out:
# -------------------- 1
# next_nodes_1 = ['123045786']
# visited_nodes_1 = {'123045786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
#
# next_nodes_2 = ['123456780']
# visited_nodes_2 = {'123456780'}
# node_2 = 123456780
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 2
# next_nodes_1 = ['023145786', '123405786', '123745086']
# visited_nodes_1 = {'023145786', '123045786', '123405786', '123745086'}
#
# Initial board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123450786', '123456708']
# visited_nodes_2 = {'123456708', '123450786', '123456780'}
# node_2 = 123450786
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# -------------------- 3
# next_nodes_1 = ['123405786', '123745086', '203145786']
# visited_nodes_1 = {'023145786', '123405786', '123745086', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
#
# next_nodes_2 = ['123456708', '120453786', '123405786']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '120453786'}
# node_2 = 123456708
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 0 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# -------------------- 4
# next_nodes_1 = ['123745086', '203145786', '103425786', '123450786', '123485706']
# visited_nodes_1 = {'023145786', '123405786', '103425786', '123450786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 0 | 6
#
#
# next_nodes_2 = ['120453786', '123405786', '123406758', '123456078']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '123456078', '123406758', '120453786'}
# node_2 = 120453786
# source = 123045786
#
# Initial board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# -------------------- 5
# next_nodes_1 = ['203145786', '103425786', '123450786', '123485706', '123745806']
# visited_nodes_1 = {'023145786', '123405786', '103425786', '123450786', '123745806', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 3 | 0
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 4 | 3
# ---------
# 1 | 0 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123405786', '123406758', '123456078', '102453786']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '123456078', '123406758', '102453786', '120453786'}
# node_2 = 123405786
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
# -------------------- 6
# next_nodes_1 = ['103425786', '123450786', '123485706', '123745806', '230145786', '243105786']
# visited_nodes_1 = {'230145786', '023145786', '123405786', '103425786', '123450786', '123745806', '243105786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 3 | 0
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123406758', '123456078', '102453786', '103425786', '123045786', '123485706']
# visited_nodes_2 = {'123456708', '123405786', '103425786', '123450786', '123456780', '123456078', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 123406758
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 6 | 0
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 7
# next_nodes_1 = ['123450786', '123485706', '123745806', '230145786', '243105786', '013425786', '130425786']
# visited_nodes_1 = {'230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
#
# next_nodes_2 = ['123456078', '102453786', '103425786', '123045786', '123485706', '103426758', '123046758', '123460758']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '123405786', '103425786', '123450786', '123456780', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 123456078
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 0 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 5 | 6
# ---------
# 4 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 8
# next_nodes_1 = ['123485706', '123745806', '230145786', '243105786', '013425786', '130425786', '120453786', '123456780']
# visited_nodes_1 = {'230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '123456780', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786', '120453786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 0 | 7 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 6 | 0
#
#
# next_nodes_2 = ['102453786', '103425786', '123045786', '123485706', '103426758', '123046758', '123460758', '123056478']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '123405786', '103425786', '123450786', '123456780', '123056478', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 102453786
# source = 123045786
#
# Initial board
# 1 | 0 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 5 | 2
# ---------
# 4 | 0 | 3
# ---------
# 7 | 8 | 6
#
# -------------------- 9
# next_nodes_1 = ['123745806', '230145786', '243105786', '013425786', '130425786', '120453786', '123456780', '123485076', '123485760']
# visited_nodes_1 = {'123485760', '230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '123456780', '123485076', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786', '120453786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 0 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 0 | 5
# ---------
# 8 | 4 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 6 | 0
#
#
# next_nodes_2 = ['103425786', '123045786', '123485706', '103426758', '123046758', '123460758', '123056478', '012453786', '152403786']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '152403786', '123405786', '103425786', '123450786', '123456780', '123056478', '012453786', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 103425786
# source = 123045786
#
# Initial board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 3 | 0
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# -------------------- 10
# next_nodes_1 = ['230145786', '243105786', '013425786', '130425786', '120453786', '123456780', '123485076', '123485760', '123705846', '123745860']
# visited_nodes_1 = {'123405786', '123450786', '123045786', '023145786', '123705846', '123485076', '130425786', '243105786', '123485706', '203145786', '123456780', '123485760', '230145786', '013425786', '120453786', '123745860', '103425786', '123745086', '123745806'}
#
# Initial board
# 2 | 3 | 0
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 3 | 5
# ---------
# 1 | 4 | 0
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123045786', '123485706', '103426758', '123046758', '123460758', '123056478', '012453786', '152403786', '013425786', '130425786']
# visited_nodes_2 = {'123460758', '123405786', '012453786', '123450786', '123056478', '102453786', '123045786', '130425786', '123485706', '123456780', '013425786', '103426758', '123046758', '123456078', '120453786', '152403786', '123456708', '103425786', '123406758'}
# node_2 = 123045786
# source = 123045786
#
# * Source reached!

# %%
print('initial board')
print_board(initial_board)
print('\n\ntarget board')
print_board(target_board)
# Out:
# initial board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
#
# target board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0

# %%
print('Operations performed = {}'.format(operations_performed))
print('Number of steps = {}\n'.format(len(steps) - 1))

for index in range(1, len(steps)):
    print('Paso #{}'.format(index))
    print_board(steps[index])
    print('\n')
# Out:
# Operations performed = 47
# Number of steps = 3
#
# Paso #1
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
#
# Paso #2
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
#
# Paso #3
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0

# %% [markdown]
# ## Example 2

# %%
initial_board_2 = [
    1, 2, 0,
    4, 5, 3,
    7, 8, 6
]

# %%
operations_performed, steps, path = bfs(initial_board_2, target_board)
# Out:
# -------------------- 1
# next_nodes_1 = ['123045786']
# visited_nodes_1 = {'123045786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
#
# next_nodes_2 = ['123456780']
# visited_nodes_2 = {'123456780'}
# node_2 = 123456780
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 2
# next_nodes_1 = ['023145786', '123405786', '123745086']
# visited_nodes_1 = {'023145786', '123045786', '123405786', '123745086'}
#
# Initial board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123450786', '123456708']
# visited_nodes_2 = {'123456708', '123450786', '123456780'}
# node_2 = 123450786
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# -------------------- 3
# next_nodes_1 = ['123405786', '123745086', '203145786']
# visited_nodes_1 = {'023145786', '123405786', '123745086', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
#
# next_nodes_2 = ['123456708', '120453786', '123405786']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '120453786'}
# node_2 = 123456708
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 0 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# -------------------- 4
# next_nodes_1 = ['123745086', '203145786', '103425786', '123450786', '123485706']
# visited_nodes_1 = {'023145786', '123405786', '103425786', '123450786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 0 | 6
#
#
# next_nodes_2 = ['120453786', '123405786', '123406758', '123456078']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '123456078', '123406758', '120453786'}
# node_2 = 120453786
# source = 123045786
#
# Initial board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# -------------------- 5
# next_nodes_1 = ['203145786', '103425786', '123450786', '123485706', '123745806']
# visited_nodes_1 = {'023145786', '123405786', '103425786', '123450786', '123745806', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 3 | 0
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 4 | 3
# ---------
# 1 | 0 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123405786', '123406758', '123456078', '102453786']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '123456078', '123406758', '102453786', '120453786'}
# node_2 = 123405786
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
# -------------------- 6
# next_nodes_1 = ['103425786', '123450786', '123485706', '123745806', '230145786', '243105786']
# visited_nodes_1 = {'230145786', '023145786', '123405786', '103425786', '123450786', '123745806', '243105786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 3 | 0
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123406758', '123456078', '102453786', '103425786', '123045786', '123485706']
# visited_nodes_2 = {'123456708', '123405786', '103425786', '123450786', '123456780', '123456078', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 123406758
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 6 | 0
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 7
# next_nodes_1 = ['123450786', '123485706', '123745806', '230145786', '243105786', '013425786', '130425786']
# visited_nodes_1 = {'230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
#
# next_nodes_2 = ['123456078', '102453786', '103425786', '123045786', '123485706', '103426758', '123046758', '123460758']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '123405786', '103425786', '123450786', '123456780', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 123456078
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 0 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 5 | 6
# ---------
# 4 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 8
# next_nodes_1 = ['123485706', '123745806', '230145786', '243105786', '013425786', '130425786', '120453786', '123456780']
# visited_nodes_1 = {'230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '123456780', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786', '120453786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 0 | 7 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 6 | 0
#
#
# next_nodes_2 = ['102453786', '103425786', '123045786', '123485706', '103426758', '123046758', '123460758', '123056478']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '123405786', '103425786', '123450786', '123456780', '123056478', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 102453786
# source = 123045786
#
# Initial board
# 1 | 0 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 5 | 2
# ---------
# 4 | 0 | 3
# ---------
# 7 | 8 | 6
#
# -------------------- 9
# next_nodes_1 = ['123745806', '230145786', '243105786', '013425786', '130425786', '120453786', '123456780', '123485076', '123485760']
# visited_nodes_1 = {'123485760', '230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '123456780', '123485076', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786', '120453786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 0 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 0 | 5
# ---------
# 8 | 4 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 6 | 0
#
#
# next_nodes_2 = ['103425786', '123045786', '123485706', '103426758', '123046758', '123460758', '123056478', '012453786', '152403786']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '152403786', '123405786', '103425786', '123450786', '123456780', '123056478', '012453786', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 103425786
# source = 123045786
#
# Initial board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 3 | 0
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# -------------------- 10
# next_nodes_1 = ['230145786', '243105786', '013425786', '130425786', '120453786', '123456780', '123485076', '123485760', '123705846', '123745860']
# visited_nodes_1 = {'123405786', '123450786', '123045786', '023145786', '123705846', '123485076', '130425786', '243105786', '123485706', '203145786', '123456780', '123485760', '230145786', '013425786', '120453786', '123745860', '103425786', '123745086', '123745806'}
#
# Initial board
# 2 | 3 | 0
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 3 | 5
# ---------
# 1 | 4 | 0
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123045786', '123485706', '103426758', '123046758', '123460758', '123056478', '012453786', '152403786', '013425786', '130425786']
# visited_nodes_2 = {'123460758', '123405786', '012453786', '123450786', '123056478', '102453786', '123045786', '130425786', '123485706', '123456780', '013425786', '103426758', '123046758', '123456078', '120453786', '152403786', '123456708', '103425786', '123406758'}
# node_2 = 123045786
# source = 123045786
#
# * Source reached!

# %%
print('initial board 2')
print_board(initial_board_2)
print('\n\ntarget board')
print_board(target_board)
# Out:
# initial board 2
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
#
# target board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0

# %%
print('Operations performed = {}'.format(operations_performed))
print('Number of steps = {}\n'.format(len(steps) - 1))

for index in range(1, len(steps)):
    print('Paso #{}'.format(index))
    print_board(steps[index])
    print('\n')
# Out:
# Operations performed = 47
# Number of steps = 2
#
# Paso #1
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
#
# Paso #2
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0

# %% [markdown]
# ## Example 3

# %%
initial_board_3 = [
    1, 2, 3,
    4, 5, 6,
    0, 7, 8
]

# %%
operations_performed, steps, path = bfs(initial_board_3, target_board)
# Out:
# -------------------- 1
# next_nodes_1 = ['123045786']
# visited_nodes_1 = {'123045786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
#
# next_nodes_2 = ['123456780']
# visited_nodes_2 = {'123456780'}
# node_2 = 123456780
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 2
# next_nodes_1 = ['023145786', '123405786', '123745086']
# visited_nodes_1 = {'023145786', '123045786', '123405786', '123745086'}
#
# Initial board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123450786', '123456708']
# visited_nodes_2 = {'123456708', '123450786', '123456780'}
# node_2 = 123450786
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# -------------------- 3
# next_nodes_1 = ['123405786', '123745086', '203145786']
# visited_nodes_1 = {'023145786', '123405786', '123745086', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
#
# next_nodes_2 = ['123456708', '120453786', '123405786']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '120453786'}
# node_2 = 123456708
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 0 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
# -------------------- 4
# next_nodes_1 = ['123745086', '203145786', '103425786', '123450786', '123485706']
# visited_nodes_1 = {'023145786', '123405786', '103425786', '123450786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 0 | 6
#
#
# next_nodes_2 = ['120453786', '123405786', '123406758', '123456078']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '123456078', '123406758', '120453786'}
# node_2 = 120453786
# source = 123045786
#
# Initial board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# -------------------- 5
# next_nodes_1 = ['203145786', '103425786', '123450786', '123485706', '123745806']
# visited_nodes_1 = {'023145786', '123405786', '103425786', '123450786', '123745806', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 2 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 3 | 0
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 4 | 3
# ---------
# 1 | 0 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123405786', '123406758', '123456078', '102453786']
# visited_nodes_2 = {'123456708', '123405786', '123450786', '123456780', '123456078', '123406758', '102453786', '120453786'}
# node_2 = 123405786
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
# -------------------- 6
# next_nodes_1 = ['103425786', '123450786', '123485706', '123745806', '230145786', '243105786']
# visited_nodes_1 = {'230145786', '023145786', '123405786', '103425786', '123450786', '123745806', '243105786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 3 | 0
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123406758', '123456078', '102453786', '103425786', '123045786', '123485706']
# visited_nodes_2 = {'123456708', '123405786', '103425786', '123450786', '123456780', '123456078', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 123406758
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 0 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 0 | 3
# ---------
# 4 | 2 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 4 | 6
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 6 | 0
# ---------
# 7 | 5 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 7
# next_nodes_1 = ['123450786', '123485706', '123745806', '230145786', '243105786', '013425786', '130425786']
# visited_nodes_1 = {'230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 0
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
#
#
# next_nodes_2 = ['123456078', '102453786', '103425786', '123045786', '123485706', '103426758', '123046758', '123460758']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '123405786', '103425786', '123450786', '123456780', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 123456078
# source = 123045786
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 0 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 0 | 5 | 6
# ---------
# 4 | 7 | 8
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
# -------------------- 8
# next_nodes_1 = ['123485706', '123745806', '230145786', '243105786', '013425786', '130425786', '120453786', '123456780']
# visited_nodes_1 = {'230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '123456780', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786', '120453786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 0 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 0 | 7 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 8 | 5
# ---------
# 7 | 6 | 0
#
#
# next_nodes_2 = ['102453786', '103425786', '123045786', '123485706', '103426758', '123046758', '123460758', '123056478']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '123405786', '103425786', '123450786', '123456780', '123056478', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 102453786
# source = 123045786
#
# Initial board
# 1 | 0 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 2
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 0
# ---------
# 4 | 5 | 3
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 5 | 2
# ---------
# 4 | 0 | 3
# ---------
# 7 | 8 | 6
#
# -------------------- 9
# next_nodes_1 = ['123745806', '230145786', '243105786', '013425786', '130425786', '120453786', '123456780', '123485076', '123485760']
# visited_nodes_1 = {'123485760', '230145786', '013425786', '023145786', '123405786', '103425786', '123450786', '123745806', '123456780', '123485076', '130425786', '243105786', '123745086', '123485706', '123045786', '203145786', '120453786'}
#
# Initial board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 0 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 0 | 5
# ---------
# 8 | 4 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 0 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 7 | 4 | 5
# ---------
# 8 | 6 | 0
#
#
# next_nodes_2 = ['103425786', '123045786', '123485706', '103426758', '123046758', '123460758', '123056478', '012453786', '152403786']
# visited_nodes_2 = {'123046758', '123460758', '123456708', '152403786', '123405786', '103425786', '123450786', '123456780', '123056478', '012453786', '123456078', '103426758', '123406758', '123485706', '102453786', '123045786', '120453786'}
# node_2 = 103425786
# source = 123045786
#
# Initial board
# 1 | 0 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 0 | 1 | 3
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 3 | 0
# ---------
# 4 | 2 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 1 | 2 | 3
# ---------
# 4 | 0 | 5
# ---------
# 7 | 8 | 6
#
# -------------------- 10
# next_nodes_1 = ['230145786', '243105786', '013425786', '130425786', '120453786', '123456780', '123485076', '123485760', '123705846', '123745860']
# visited_nodes_1 = {'123405786', '123450786', '123045786', '023145786', '123705846', '123485076', '130425786', '243105786', '123485706', '203145786', '123456780', '123485760', '230145786', '013425786', '120453786', '123745860', '103425786', '123745086', '123745806'}
#
# Initial board
# 2 | 3 | 0
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 0 | 3
# ---------
# 1 | 4 | 5
# ---------
# 7 | 8 | 6
#
# New board
# 2 | 3 | 5
# ---------
# 1 | 4 | 0
# ---------
# 7 | 8 | 6
#
#
# next_nodes_2 = ['123045786', '123485706', '103426758', '123046758', '123460758', '123056478', '012453786', '152403786', '013425786', '130425786']
# visited_nodes_2 = {'123460758', '123405786', '012453786', '123450786', '123056478', '102453786', '123045786', '130425786', '123485706', '123456780', '013425786', '103426758', '123046758', '123456078', '120453786', '152403786', '123456708', '103425786', '123406758'}
# node_2 = 123045786
# source = 123045786
#
# * Source reached!

# %%
print('initial board 3')
print_board(initial_board_3)
print('\n\ntarget board')
print_board(target_board)
# Out:
# initial board 3
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 0 | 7 | 8
#
#
# target board
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0

# %%
print('Operations performed = {}'.format(operations_performed))
print('Number of steps = {}\n'.format(len(steps) - 1))

for index in range(1, len(steps)):
    print('Paso #{}'.format(index))
    print_board(steps[index])
    print('\n')
# Out:
# Operations performed = 47
# Number of steps = 2
#
# Paso #1
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 0 | 8
#
#
# Paso #2
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 0
